# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/morph.jpg') 
kernel = np.ones((5,5),np.uint8)
plt.imshow(img)

# %%
img_erosion = cv2.erode(img, kernel, iterations = 1)
plt.imshow(img_erosion)
plt.title("eroded image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(659.5), np.float64(557.5), np.float64(-0.5))

# %%
img_dilation = cv2.dilate(img, kernel, iterations = 1)
plt.imshow(img_dilation)

# %%
img_opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel, iterations = 1)
plt.imshow(img_opening)

# %%
img_closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel, iterations=1)
plt.imshow(img_closing)

# %%
img_morph_gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
plt.imshow(img_morph_gradient)
