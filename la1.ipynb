# %% [markdown]
# # write a program in python to perform various basic image processing operations: Reading image, Writing image, conversion of images, and complement of an image using OpenCV

# %%
import cv2

# %%
image = cv2.imread("./images/tiger.jpg")
if image is not None:
    cv2.imshow("image", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Image not found")
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/sharvin/Documents/CV LAB/opencv/lib/python3.14/site-packages/cv2/qt/plugins"
# QFontDatabase: Cannot find font directory /home/sharvin/Documents/CV LAB/opencv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/sharvin/Documents/CV LAB/opencv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/sharvin/Documents/CV LAB/opencv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ...

# %%
cv2.imwrite('image_output.jpg', image)
# Out:
# True

# %%
# 3. Convert Image (Color to Grayscale)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Grayscale Image", gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Save grayscale image
cv2.imwrite('output_gray.jpg', gray_image)
# Out:
# True

# %%
complement_img = 255 - image
cv2.imshow('Complement image: ', complement_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('Complement_output.jpg', complement_img)
# Out:
# True
